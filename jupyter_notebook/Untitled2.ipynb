# %%
import numpy as np
from bokeh.io import show, output_file, output_notebook
from bokeh.plotting import figure
from bokeh import events
from bokeh.models import CustomJS, Div
from bokeh.layouts import column, row
import datetime
from bokeh.models.widgets import TextInput, Button
 # stupid method, add the stock ticker as a column to the dataframe and use that as column data. 
output_notebook()

stock_ticker = ""

def set_stock_ticker():
    return CustomJS(code="""
        val stock = cb_obj.value
    """)
    
def test_button():
    return CustomJS(code="""
        window.open("https://www.google.com")
    """)

def display_event(div, attributes=[], style = 'float:left;clear:left;font_size=0.5pt'):
    "Build a suitable CustomJS to display the current event in the div model."
    return CustomJS(args=dict(div=div), code="""
        var url = "https://www.google.com/search?q="
        var attrs = %s; var args = [];
        for (var i=0; i<attrs.length; i++ ) {
            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));
        }
        var line = "<span style=%r><b>" + cb_obj.event_name + "</b>(" + args.join(", ") + ")</span>\\n";
        var text = div.text.concat(line);
        var lines = text.split("\\n")
        if ( lines.length > 35 ) { lines.shift(); }
        div.text = lines.join("\\n");
        var myDate = new Date(Math.trunc(cb_obj[attrs[0]]) * 1000);
        var month = myDate.getMonth() + 1
        window.open(url + myDate + month + stock)
    """ % (attributes, style))

text_input = TextInput(value="default", title="Label:")
text_input.js_on_change('value', set_stock_ticker())
button = Button(label="Foo", button_type="success")
button.on_click(set_stock_ticker)
button.js_on_event(events.ButtonClick, test_button())

base = datetime.datetime.today() 
x = [base - datetime.timedelta(days=x) for x in range(0, 4000)]
#x = np.random.random(size=4000) * 100
y = np.random.random(size=4000) * 100
radii = np.random.random(size=4000) * 1.5
#colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)]

p = figure(tools="pan,wheel_zoom,zoom_in,zoom_out,reset")
p.scatter(x, y, radius=np.random.random(size=4000) * 1.5,
           fill_alpha=0.6, line_color=None)

div = Div(width=1000)
layout = column(row(text_input, button), row(p, div)) #column and rows will autofit the entities into given screen. nice for formatting.
point_attributes = ['x','y','sx','sy']                     # Point events

point_events =  [events.Tap, events.DoubleTap, events.Press, 
                 events.MouseMove, events.MouseEnter, events.MouseLeave]

for event in point_events:
    p.js_on_event(event,display_event(div, attributes=point_attributes))
output_file("js_events.html", title="JS Events Example")
show(layout)
show(widgetbox(text_input))
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7330b760-7576-4867-844b-28a89b1733c3">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4537a12b-f54f-4c61-b771-5e1b6cd167a4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...
